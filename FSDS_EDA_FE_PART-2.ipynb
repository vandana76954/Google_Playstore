# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("C:/Users/aru78/INEURON DATA/Untitled Folder/clean_google_playstore_data.csv")

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10835                               Sya9a Maroc - FR               FAMILY
# 10836               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                         Parkinson Exercices FR              MEDICAL
# 10838                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# 10835     4.5       38  53000.0      5000  Free    0.0       Everyone
# 10836     5.0        4   3600.0       100  Free    0.0       Everyone
# 10837     NaN        3   9500.0      1000  Free    0.0       Everyone
# 10838     4.5      114      NaN      1000  Free    0.0     Mature 17+
# 10839     4.5   398307  19000.0  10000000  Free    0.0       Everyone
#
#                   Genres Last Updated         Current Ver Android Ver  Day  \
# ...

# %%
df.shape
# Out:
# (10840, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     9476 non-null   object
#  13  Day             10840 non-null  int64
#  14  Month           10840 non-null  int64
#  15  Year            10840 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# ...

# %%
df.describe().T
# Out:
#             count          mean           std     min     25%       50%  \
# Rating     9366.0  4.191757e+00  5.152189e-01     1.0     4.0       4.3
# Reviews   10840.0  4.441529e+05  2.927761e+06     0.0    38.0    2094.0
# Size       9145.0  2.150653e+04  2.259602e+04    10.0  4900.0   13000.0
# Installs  10840.0  1.546434e+07  8.502936e+07     0.0  1000.0  100000.0
# Price     10840.0  1.027368e+00  1.594970e+01     0.0     0.0       0.0
# Day       10840.0  1.560904e+01  9.561621e+00     1.0     6.0      16.0
# Month     10840.0  6.422325e+00  2.578388e+00     1.0     5.0       7.0
# Year      10840.0  2.017400e+03  1.100914e+00  2010.0  2017.0    2018.0
#
#                 75%           max
# Rating          4.5  5.000000e+00
# Reviews     54775.5  7.815831e+07
# Size        30000.0  1.000000e+05
# Installs  5000000.0  1.000000e+09
# Price           0.0  4.000000e+02
# Day            24.0  3.100000e+01
# Month           8.0  1.200000e+01
# Year         2018.0  2.018000e+03

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Day', 'Month', 'Year'],
#       dtype='object')

# %%
#483 duplicated rows are there in entire datframe
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10767                                             AAFP       MEDICAL     3.8
#
# ...

# %%
#if we want to check duplicated values w.r.t to particular column
df[df.duplicated("Reviews")]
# Out:
#                                           App             Category  Rating  \
# 4       Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN     4.3
# 57                 Extreme Rally Championship    AUTO_AND_VEHICLES     4.2
# 126              Skin Care and Natural Beauty               BEAUTY     NaN
# 134             Lady adviser (beauty, health)               BEAUTY     NaN
# 156    Offline: English to Tagalog Dictionary  BOOKS_AND_REFERENCE     4.7
# ...                                       ...                  ...     ...
# 10834                                FR Forms             BUSINESS     NaN
# 10835                        Sya9a Maroc - FR               FAMILY     4.5
# 10836        Fr. Mike Schmitz Audio Teachings               FAMILY     5.0
# 10837                  Parkinson Exercices FR              MEDICAL     NaN
# 10838           The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE     4.5
#
#        Reviews     Size  Installs  Type  Price Content Rating  \
# ...

# %%
#droping duplicate values w.r.t to App name category
df = df.drop_duplicates(subset=["App"],keep="first")

# %%
#Now we have 9659 rows left out of 10480
df.shape
# Out:
# (9659, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9659 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   int64
#  4   Size            8432 non-null   float64
#  5   Installs        9659 non-null   int64
#  6   Type            9658 non-null   object
#  7   Price           9659 non-null   float64
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   object
#  11  Current Ver     9651 non-null   object
#  12  Android Ver     8667 non-null   object
#  13  Day             9659 non-null   int64
#  14  Month           9659 non-null   int64
#  15  Year            9659 non-null   int64
# dtypes: float64(3), int64(5), object(8)
# ...

# %%
numeric_features = [feature for feature in df.columns if df[feature].dtype !='O']

# %%
numeric_features
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'Day', 'Month', 'Year']

# %%
df[numeric_features]
# Out:
#        Rating  Reviews     Size  Installs  Price  Day  Month  Year
# 0         4.1      159  19000.0     10000    0.0    7      1  2018
# 1         3.9      967  14000.0    500000    0.0   15      1  2018
# 2         4.7    87510   8700.0   5000000    0.0    1      8  2018
# 3         4.5   215644  25000.0  50000000    0.0    8      6  2018
# 4         4.3      967   2800.0    100000    0.0   20      6  2018
# ...       ...      ...      ...       ...    ...  ...    ...   ...
# 10835     4.5       38  53000.0      5000    0.0   25      7  2017
# 10836     5.0        4   3600.0       100    0.0    6      7  2018
# 10837     NaN        3   9500.0      1000    0.0   20      1  2017
# 10838     4.5      114      NaN      1000    0.0   19      1  2015
# 10839     4.5   398307  19000.0  10000000    0.0   25      7  2018
#
# [9659 rows x 8 columns]

# %%
categorical_features = [feature for feature in df.columns if df[feature].dtype =='O']

# %%
categorical_features
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
df[categorical_features]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# #### Categorical Features

# %%
df["Type"].value_counts()
# Out:
# Free    8902
# Paid     756
# Name: Type, dtype: int64

# %%
#For percentage
df["Type"].value_counts(normalize=True)*100
# Out:
# Free    92.172292
# Paid     7.827708
# Name: Type, dtype: float64

# %%
for col in categorical_features:
    print(col)
# Out:
# App
# Category
# Type
# Content Rating
# Genres
# Last Updated
# Current Ver
# Android Ver

# %%
for col in categorical_features:
    print(f"{col} : {df[col].value_counts(normalize=True)*100}")
    print("*************************************************")
# Out:
# App : Tozer Devotional -Series 1                         0.010353
# Epson iProjection                                  0.010353
# dB Sound Meter                                     0.010353
# AJ Gray Icon Pack                                  0.010353
# Batman: Gotham’s Most Wanted!                      0.010353
#                                                      ...
# Puppy Shooting an AK-47: Platformer Zombie Game    0.010353
# Learn English from Persian: Persian to English     0.010353
# Amino: Communities and Chats                       0.010353
# BZ Conferencing                                    0.010353
# Droid Zap by Motorola                              0.010353
# Name: App, Length: 9659, dtype: float64
# *************************************************
# Category : FAMILY                 18.966767
# GAME                    9.928564
# TOOLS                   8.561963
# BUSINESS                4.348276
# MEDICAL                 4.089450
# PERSONALIZATION         3.892743
# ...

# %%
sns.countplot(x=df["Type"])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
sns.countplot(x=df["Content Rating"])
# Out:
# <AxesSubplot:xlabel='Content Rating', ylabel='count'>

# %%
#Category wise plot graph using for loop
plt.figure(figsize=(20,15))
plt.suptitle("Univariare Analysis of Categorical features",fontsize=20,fontweight='bold',alpha=0.8,y=1.)
category=["Type","Content Rating"]
for i in range(0,len(category)):
    plt.subplot(2,2,i+1)
    sns.countplot(x=df[category[i]], palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %% [markdown]
# ### Numeric Features

# %%
numeric_features
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'Day', 'Month', 'Year']

# %%
sns.kdeplot(df["Price"])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
sns.distplot(df['Reviews'])
# Out:
# <AxesSubplot:xlabel='Reviews', ylabel='Density'>

# %%
sns.distplot(df['Rating'])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Density'>

# %%
plt.hist(df["Rating"])
plt.show()

# %%
#Numeric variables plot graph using for loop
plt.figure(figsize=(15,15))
plt.suptitle("Univariate Analysis of Numeric features",fontsize=20,fontweight='bold',alpha=0.8,y=1.)

for i in range(0,len(numeric_features)):
    plt.subplot(5,3,i+1)
    sns.kdeplot(x=df[numeric_features[i]],shade=True,color='r')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
#Most popular category in app
df["Category"].value_counts().plot.pie(y=df["Category"],figsize=(15,15),autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Category'>

# %% [markdown]
# We can see that popular category is Family followed by Game and Tools.On the other hand,Beauty is the least popular category

# %%
#Top 10 Category
df_cat=df["Category"].value_counts()[:10]

# %%
category = pd.DataFrame(df['Category'].value_counts())        #Dataframe of apps on the basis of category
category.rename(columns = {'Category':'Count'},inplace=True)

# %%
plt.figure(figsize=(15,8))
sns.barplot(x=df_cat,y="Count", data=category[:10],palette='hls' )
plt.title('Top 10 App categories')
plt.xticks(rotation=90)
plt.show()

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
#which category having largest number of installaion

# %%
#which category has the largest number of installations
#reset_index to get in dataframe
df_cat_installs=df.groupby(['Category'])['Installs'].sum().sort_values(ascending=False).reset_index()

# %%
#Top 10 category with highest installations
df2=df_cat_installs.head(10)

# %%
df2
# Out:
#              Category     Installs
# 0                GAME  13878924415
# 1       COMMUNICATION  11038276251
# 2               TOOLS   8001771915
# 3        PRODUCTIVITY   5793091369
# 4              SOCIAL   5487867902
# 5         PHOTOGRAPHY   4649147655
# 6              FAMILY   4427941505
# 7       VIDEO_PLAYERS   3926902720
# 8    TRAVEL_AND_LOCAL   2894887146
# 9  NEWS_AND_MAGAZINES   2369217760

# %%
#Plotting the graph
sns.barplot(x="Installs",y="Category",data=df2)
# Out:
# <AxesSubplot:xlabel='Installs', ylabel='Category'>

# %%
plt.figure(figsize = (14,10))
sns.set_context("talk")
sns.set_style("darkgrid")

ax = sns.barplot(x = 'Installs' , y = 'Category' , data = df2 )
ax.set_xlabel('No. of Installations in Billions')
ax.set_ylabel('')
ax.set_title("Most Popular Categories in Play Store", size = 20)
# Out:
# Text(0.5, 1.0, 'Most Popular Categories in Play Store')

# %% [markdown]
# Game category seems to have maximum installations which means it is the most popular category

# %%
#What are the Top 5 most installed Apps in Each popular Categories ??

# %%
dfa=df.groupby(['Category','App'])['Installs'].sum().reset_index()

# %%
dfa
# Out:
#             Category                                                App  \
# 0     ART_AND_DESIGN                           350 Diy Room Decor Ideas
# 1     ART_AND_DESIGN    3D Color Pixel by Number - Sandbox Art Coloring
# 2     ART_AND_DESIGN                            AJ Styles HD Wallpapers
# 3     ART_AND_DESIGN  AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper
# 4     ART_AND_DESIGN                              Ai illustrator viewer
# ...              ...                                                ...
# 9654         WEATHER                                      Yahoo Weather
# 9655         WEATHER  Yahoo! Weather for SH Forecast for understandi...
# 9656         WEATHER                                     Yandex.Weather
# 9657         WEATHER                         weather - weather forecast
# 9658         WEATHER                     wetter.com - Weather and Radar
#
#       Installs
# 0        10000
# 1       100000
# 2         5000
# 3         1000
# 4       100000
# ...

# %%
dfa=dfa.sort_values('Installs',ascending=False)

# %%
dfa[dfa.Category=='GAME'][:5]
# Out:
#      Category               App    Installs
# 4773     GAME    Subway Surfers  1000000000
# 4167     GAME  Candy Crush Saga   500000000
# 4628     GAME               Pou   500000000
# 4802     GAME      Temple Run 2   500000000
# 4580     GAME    My Talking Tom   500000000

# %%
dfa[dfa.Category=='PRODUCTIVITY'][:5]
# Out:
#           Category              App    Installs
# 7427  PRODUCTIVITY     Google Drive  1000000000
# 7472  PRODUCTIVITY   Microsoft Word   500000000
# 7425  PRODUCTIVITY  Google Calendar   500000000
# 7364  PRODUCTIVITY          Dropbox   500000000
# 7334  PRODUCTIVITY      Cloud Print   500000000

# %%
dfa[dfa.Category=='TOOLS'][:5]
# Out:
#      Category                                                App    Installs
# 8837    TOOLS                                             Google  1000000000
# 9038    TOOLS  Security Master - Antivirus, VPN, AppLock, Boo...   500000000
# 9016    TOOLS                         SHAREit - Transfer & Share   500000000
# 8842    TOOLS                                   Google Translate   500000000
# 8835    TOOLS                       Gboard - the Google Keyboard   500000000

# %%
#Top 5 app installatiions in Communication  category\
dfa[dfa.Category=='COMMUNICATION'][:5]
# Out:
#            Category                            App    Installs
# 1145  COMMUNICATION  Skype - free IM & video calls  1000000000
# 1181  COMMUNICATION             WhatsApp Messenger  1000000000
# 1064  COMMUNICATION                       Hangouts  1000000000
# 1058  COMMUNICATION   Google Chrome: Fast & Secure  1000000000
# 1055  COMMUNICATION                          Gmail  1000000000

# %%
#Top 5 app installatiions in Tools category\
dfa[dfa["Category"]=='SOCIAL'][:5]
# Out:
#      Category            App    Installs
# 7883   SOCIAL       Facebook  1000000000
# 7908   SOCIAL        Google+  1000000000
# 7919   SOCIAL      Instagram  1000000000
# 7984   SOCIAL       Snapchat   500000000
# 7885   SOCIAL  Facebook Lite   500000000

# %%
#We can also do it using for loop
apps = ['GAME', 'COMMUNICATION', 'PRODUCTIVITY', 'SOCIAL' ]
sns.set_context("poster")
sns.set_style("darkgrid")

plt.figure(figsize=(40,30))

for i,app in enumerate(apps):
    df2 = dfa[dfa.Category == app]
    df3 = df2.head(5)
    plt.subplot(4,2,i+1)
    sns.barplot(data= df3,x= 'Installs' ,y='App' )
    plt.xlabel('Installation in Millions')
    plt.ylabel('')
    plt.title(app,size = 20)
    
plt.tight_layout()
plt.subplots_adjust(hspace= .3)
plt.show()

# %%
#How many apps are there on Google Play Store which get 5 ratings??

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
rating=df.groupby(df["App"])["Rating"].sum().sort_values(ascending=False).reset_index()

# %%
rating
# Out:
#                                           App  Rating
# 0                               Story Time FD     5.0
# 1                                     CG Jobs     5.0
# 2                                 CL Notifier     5.0
# 3     CL Keyboard - Myanmar Keyboard (No Ads)     5.0
# 4                          CK Employee Portal     5.0
# ...                                       ...     ...
# 9654                             EP Cook Book     0.0
# 9655                                EP Coding     0.0
# 9656     BM Tahmin: Ücretsiz İddaa Tahminleri     0.0
# 9657                                 EP Cloud     0.0
# 9658     "i DT" Fútbol. Todos Somos Técnicos.     0.0
#
# [9659 rows x 2 columns]

# %%
rating.Rating==5.0
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 9654    False
# 9655    False
# 9656    False
# 9657    False
# 9658    False
# Name: Rating, Length: 9659, dtype: bool

# %%
rating[rating.Rating==5.0]
# Out:
#                                            App  Rating
# 0                                Story Time FD     5.0
# 1                                      CG Jobs     5.0
# 2                                  CL Notifier     5.0
# 3      CL Keyboard - Myanmar Keyboard (No Ads)     5.0
# 4                           CK Employee Portal     5.0
# ..                                         ...     ...
# 266  TI-84 CE Graphing Calculator Manual TI 84     5.0
# 267              American Girls Mobile Numbers     5.0
# 268                     AJ Gray Dark Icon Pack     5.0
# 269              R Programing Offline Tutorial     5.0
# 270                          AJ Blue Icon Pack     5.0
#
# [271 rows x 2 columns]

# %%
rating2 = df.groupby(['Category','Installs', 'App'])['Rating'].sum().sort_values(ascending = False).reset_index()

# %%
rating2
# Out:
#             Category  Installs  \
# 0            FINANCE       100
# 1             FAMILY       100
# 2             FAMILY       100
# 3             FAMILY       100
# 4             FAMILY        50
# ...              ...       ...
# 9654           TOOLS        10
# 9655           TOOLS        10
# 9656           TOOLS        10
# 9657           TOOLS        10
# 9658  ART_AND_DESIGN         0
#
#                                                  App  Rating
# 0                                                 CF     5.0
# 1                                        CN Resident     5.0
# 2                                BV Sridhara Maharaj     5.0
# 3                                    BK Video Status     5.0
# 4                                          daskal.eu     5.0
# ...                                              ...     ...
# 9654  BT Position Sender - Bluetooth Position Sender     0.0
# 9655                                 BS TRACK CLIENT     0.0
# ...

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Day', 'Month', 'Year'],
#       dtype='object')

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(data=df,y="Category",x='Price')
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Category'>

# %%
#Which Category app users are reviewing the most ??

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
df.groupby(['Category','App'])["Reviews"].sum().reset_index()
# Out:
#             Category                                                App  \
# 0     ART_AND_DESIGN                           350 Diy Room Decor Ideas
# 1     ART_AND_DESIGN    3D Color Pixel by Number - Sandbox Art Coloring
# 2     ART_AND_DESIGN                            AJ Styles HD Wallpapers
# 3     ART_AND_DESIGN  AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper
# 4     ART_AND_DESIGN                              Ai illustrator viewer
# ...              ...                                                ...
# 9654         WEATHER                                      Yahoo Weather
# 9655         WEATHER  Yahoo! Weather for SH Forecast for understandi...
# 9656         WEATHER                                     Yandex.Weather
# 9657         WEATHER                         weather - weather forecast
# 9658         WEATHER                     wetter.com - Weather and Radar
#
#       Reviews
# 0          27
# 1        1518
# 2          48
# 3          18
# 4         486
# ...

# %%
df.groupby("Category").agg({"Installs":"sum","Reviews":"sum"}).reset_index()
# Out:
#                Category     Installs    Reviews
# 0        ART_AND_DESIGN    114338100    1419203
# 1     AUTO_AND_VEHICLES     53130211    1163666
# 2                BEAUTY     27197050     396240
# 3   BOOKS_AND_REFERENCE   1665969576   16721314
# 4              BUSINESS    697164865    9890245
# 5                COMICS     44981150    2342071
# 6         COMMUNICATION  11038276251  285811368
# 7                DATING    140926107    3623544
# 8             EDUCATION    352952000   13364148
# 9         ENTERTAINMENT   2113660000   34762650
# 10               EVENTS     15973161     161018
# 11               FAMILY   4427941505  143825488
# 12              FINANCE    455348734   12662106
# 13       FOOD_AND_DRINK    211798751    6325028
# 14                 GAME  13878924415  622298709
# 15   HEALTH_AND_FITNESS   1144022512   21361355
# 16       HOUSE_AND_HOME     97212461    1929847
# 17   LIBRARIES_AND_DEMO     52995910     906831
# 18            LIFESTYLE    503823539   11832671
# ...

# %%
df.groupby("Type").agg({"Installs":sum})
# Out:
#          Installs
# Type
# Free  75065572646
# Paid     57364881

# %%
df.groupby('Type').agg({'Installs':sum}).plot.pie(y='Installs', startangle=90, explode=(0.2,0), title='Percentage of Installs Number for Free App and Paid App', legend=False, autopct='%.2f')
# Out:
# <AxesSubplot:title={'center':'Percentage of Installs Number for Free App and Paid App'}, ylabel='Installs'>

# %%
df["Type"].value_counts().plot.pie(y="Type",startangle=90, explode=(0.2,0), title='Percentage of the Free App and Paid App',legend=False,autopct='%.2f')
# Out:
# <AxesSubplot:title={'center':'Percentage of the Free App and Paid App'}, ylabel='Type'>

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x="Installs",y="Rating",data=df)
plt.xticks(size=15,rotation=90)
plt.show()

# %% [markdown]
# Higher installation no outliers and rating is fine
# Avg rating of all the apps is between 4 to 4.5
# Higher installation app has a good rating

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x="Category",y="Rating",data=df)
plt.xticks(size=15,rotation=90)
plt.show()

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
#Which Category are of largest size ??

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Day', 'Month', 'Year'],
#       dtype='object')

# %%
plt.figure(figsize=(15,15))
plt.xticks(size=10,rotation = 90)
sns.barplot('Category','Size',data=df)
plt.show()

# %%
Game category has the largest Size

# %%
plt.subplots(figsize=(20,10))
freq= pd.Series()
freq=df['Year'].value_counts()
freq.plot()
plt.xlabel("Dates")
plt.ylabel("Number of updates")
plt.title("Time series plot of Last Updates")
# Out:
# Text(0.5, 1.0, 'Time series plot of Last Updates')

# %% [markdown]
# No of updates with respect to year is increasing after 2015

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
plt.figure(figsize=(15,8))
sns.countplot(x='Rating',data = df,palette="Set1_r")
plt.xticks(rotation =90)
plt.title('Countplot for ratings')             
plt.show()
